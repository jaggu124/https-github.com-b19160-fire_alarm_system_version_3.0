# %% [markdown]
# <a href="https://colab.research.google.com/github/jaggu124/https-github.com-b19160-fire_alarm_system_version_3.0/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten
import matplotlib.pyplot as plt

# %%
(X_train,y_train),(X_test,y_test) = keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
plt.imshow(X_train[0])

# %%
plt.imshow(X_train[1])

# %%
plt.imshow(X_train[2])

# %%
plt.imshow(X_train[3])

# %%
plt.imshow(X_train[4])

# %%
plt.imshow(X_train[5])

# %%
plt.imshow(X_train[8])

# %%
X_train = X_train/255
X_test = X_test/255

# %%
model = Sequential()

model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])
model.fit(X_train,y_train,epochs=10,validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2852 - accuracy: 0.9185 - val_loss: 0.1542 - val_accuracy: 0.9549
# Epoch 2/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.1270 - accuracy: 0.9629 - val_loss: 0.1181 - val_accuracy: 0.9653
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0882 - accuracy: 0.9740 - val_loss: 0.0993 - val_accuracy: 0.9703
# Epoch 4/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0662 - accuracy: 0.9801 - val_loss: 0.0952 - val_accuracy: 0.9707
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0511 - accuracy: 0.9847 - val_loss: 0.0866 - val_accuracy: 0.9742
# Epoch 6/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0402 - accuracy: 0.9877 - val_loss: 0.0831 - val_accuracy: 0.9764
# Epoch 7/10
# ...

# %%
y_prob = model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
y_prob.argmax(axis=1)
# Out:
# array([7, 2, 1, ..., 4, 5, 6])

# %%
y_pred = y_prob.argmax(axis=1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9787

# %%
history = model.fit(X_train,y_train,epochs=10,validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.1341 - val_accuracy: 0.9732
# Epoch 2/10
# 1500/1500 [==============================] - 11s 8ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.1224 - val_accuracy: 0.9787
# Epoch 3/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.1560 - val_accuracy: 0.9703
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.1283 - val_accuracy: 0.9764
# Epoch 5/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.1372 - val_accuracy: 0.9748
# Epoch 6/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.1305 - val_accuracy: 0.9762
# Epoch 7/10
# ...

# %%
y_prob = model.predict(X_test)
y_pred = y_prob.argmax(axis=1)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
plt.imshow(X_test[0])

# %%
plt.imshow(X_test[1])

# %%
plt.imshow(X_test[3])
